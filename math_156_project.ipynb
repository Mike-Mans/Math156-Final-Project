# %% [markdown]
# <a href="https://colab.research.google.com/github/Mike-Mans/Math156-Final-Project/blob/main/math_156_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install datasets torch torchvision torchaudio numpy pandas scikit-learn librosa optuna matplotlib seaborn tqdm
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.1.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.1)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.10.5)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.23)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 14.7 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0

# %%
# !wget https://huggingface.co/datasets/google/speech_commands/resolve/main/speech_commands.py
# Out:
# --2025-11-20 02:04:14--  https://huggingface.co/datasets/google/speech_commands/resolve/main/speech_commands.py
# Resolving huggingface.co (huggingface.co)... 3.165.160.12, 3.165.160.59, 3.165.160.61, ...
# Connecting to huggingface.co (huggingface.co)|3.165.160.12|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: /api/resolve-cache/datasets/google/speech_commands/57ba463ab37e1e7845e0626539a6f6d0fcfbe64a/speech_commands.py?%2Fdatasets%2Fgoogle%2Fspeech_commands%2Fresolve%2Fmain%2Fspeech_commands.py=&etag=%22a7d6c44c469bcd15ec0a0ddecfa5d509a2eed812%22 [following]
# --2025-11-20 02:04:14--  https://huggingface.co/api/resolve-cache/datasets/google/speech_commands/57ba463ab37e1e7845e0626539a6f6d0fcfbe64a/speech_commands.py?%2Fdatasets%2Fgoogle%2Fspeech_commands%2Fresolve%2Fmain%2Fspeech_commands.py=&etag=%22a7d6c44c469bcd15ec0a0ddecfa5d509a2eed812%22
# Reusing existing connection to huggingface.co:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7312 (7.1K) [text/plain]
# Saving to: ‘speech_commands.py’
#
# speech_commands.py  100%[===================>]   7.14K  --.-KB/s    in 0s
#
# 2025-11-20 02:04:15 (277 MB/s) - ‘speech_commands.py’ saved [7312/7312]

# %%
import os
import torch
import torchvision
import torchaudio
import numpy as np
import pandas as pd
import sklearn
import librosa
import optuna
import matplotlib.pyplot as plt
import seaborn as sns
import tqdm
import glob
import torch.nn as nn

# %%
# define target classes mapping
CORE_COMMANDS = ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go']
UNKNOWN_WORDS = ['bed', 'cat', 'dog', 'eight', 'five', 'four', 'happy', 'house', 'marvin', 'nine',
                 'one', 'seven', 'sheila', 'six', 'three', 'tree', 'two', 'wow', 'zero']

def get_label(word_class):
    """
    Map word class to numerical label for 12-class classification.
    Returns:
        0-9: Core command indices
        10: Unknown class (all auxiliary words)
        11: Silence class
    """
    if word_class in CORE_COMMANDS:
        return CORE_COMMANDS.index(word_class)
    elif word_class in UNKNOWN_WORDS:
        return 10  # unknown
    elif word_class == '_silence_':
        return 11  # silence
    else:
        return 10  # default to unknown

# %%
def create_silence_data():
    """
    Create silence data by slicing background noise files into 1-second chunks.

    Iterates through the long audio files in the _background_noise_ directory,
    slices them into 1-second (16,000 samples) chunks at 16kHz, and saves these chunks
    as individual WAV files in a _silence_ directory.

    Returns:
        List of paths to the generated silence audio files.
    """

    silence_dir = os.path.join(DATASET_PATH, "SpeechCommands", "speech_commands_v0.02", "_silence_")
    background_noise_dir = os.path.join(DATASET_PATH, "SpeechCommands", "speech_commands_v0.02", "_background_noise_")

    # creates silence directory if it doesn't exist
    os.makedirs(silence_dir, exist_ok=True)

    silence_files = []

    # gets all WAV files in background noise directory
    background_files = glob.glob(os.path.join(background_noise_dir, "*.wav"))

    chunk_counter = 0

    for bg_file in background_files:
        # load the background noise file
        waveform, sample_rate = torchaudio.load(bg_file)

        # ensure sample rate is 16kHz
        assert sample_rate == 16000, f"Expected 16kHz sample rate, got {sample_rate}"

        # get the waveform data
        if waveform.shape[0] > 1:
            waveform = waveform[0:1, :]  # take first channel if multi-channel

        waveform = waveform.squeeze()  # remove channel dimension for easier processing
        total_samples = waveform.shape[0]

        # calculate number of 1-second chunks (16000 samples each)
        chunk_size = 16000
        num_chunks = total_samples // chunk_size

        # slice the waveform into chunks
        for i in range(num_chunks):
            start_sample = i * chunk_size
            end_sample = start_sample + chunk_size

            chunk = waveform[start_sample:end_sample]

            # save chunk
            chunk_filename = f"silence_{chunk_counter:05d}.wav"
            chunk_path = os.path.join(silence_dir, chunk_filename)

            # save as mono WAV file
            torchaudio.save(chunk_path, chunk.unsqueeze(0), sample_rate)

            silence_files.append(chunk_path)
            chunk_counter += 1

    print(f"created {len(silence_files)} silence chunks from {len(background_files)} background noise files")
    return silence_files

# %%
def load_dataset_splits():
    """
    Load the validation and testing lists and create three master lists of file paths.

    Returns:
        train_files: List of file paths for training (all files not in validation/testing + 80% of silence)
        val_files: List of file paths for validation (files from validation_list.txt + 10% of silence)
        test_files: List of file paths for testing (files from testing_list.txt + 10% of silence)
    """
    dataset_dir = os.path.join(DATASET_PATH, "SpeechCommands", "speech_commands_v0.02")

    # load validation and testing lists
    with open(os.path.join(dataset_dir, 'validation_list.txt'), 'r') as f:
        val_lines = f.read().splitlines()
    with open(os.path.join(dataset_dir, 'testing_list.txt'), 'r') as f:
        test_lines = f.read().splitlines()

    # convert to sets for faster lookup
    val_files_set = set(val_lines)
    test_files_set = set(test_lines)

    # get all WAV files in the dataset
    all_wav_files = []
    for root, dirs, files in os.walk(dataset_dir):
        for file in files:
            if file.endswith('.wav'):
                # Get relative path from dataset directory
                rel_path = os.path.relpath(os.path.join(root, file), dataset_dir)
                all_wav_files.append(rel_path)

    # create train/val/test file lists
    train_files = []
    val_files = []
    test_files = []

    for wav_file in all_wav_files:
        if wav_file in val_files_set:
            val_files.append(os.path.join(dataset_dir, wav_file))
        elif wav_file in test_files_set:
            test_files.append(os.path.join(dataset_dir, wav_file))
        else:
            train_files.append(os.path.join(dataset_dir, wav_file))

    # handle silence files partitioning (80% train, 10% val, 10% test)
    silence_dir = "_silence_"
    if os.path.exists(silence_dir):
        silence_files = glob.glob(os.path.join(silence_dir, "*.wav"))
        silence_files.sort()  # sort for reproducible splits

        n_silence = len(silence_files)
        n_train_silence = int(0.8 * n_silence)
        n_val_silence = int(0.1 * n_silence)

        train_files.extend(silence_files[:n_train_silence])
        val_files.extend(silence_files[n_train_silence:n_train_silence + n_val_silence])
        test_files.extend(silence_files[n_train_silence + n_val_silence:])

    print(f"Dataset splits created:")
    print(f"  Training: {len(train_files)} files")
    print(f"  Validation: {len(val_files)} files")
    print(f"  Testing: {len(test_files)} files")

    return train_files, val_files, test_files

# %%
DATASET_PATH = "./speech_commands_v2"
os.makedirs(DATASET_PATH, exist_ok=True)

train_dataset = torchaudio.datasets.SPEECHCOMMANDS(
    root=DATASET_PATH,
    folder_in_archive="SpeechCommands",
    download=True,
    subset="training",
)

test_dataset = torchaudio.datasets.SPEECHCOMMANDS(
    root=DATASET_PATH,
    folder_in_archive="SpeechCommands",
    download=True,
    subset="testing",
)

valid_dataset = torchaudio.datasets.SPEECHCOMMANDS(
    root=DATASET_PATH,
    folder_in_archive="SpeechCommands",
    download=True,
    subset="validation",
)
# Out:
# 100%|██████████| 2.26G/2.26G [00:24<00:00, 101MB/s]

# %%
create_silence_data()
# Out:
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:337: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.save_with_torchcodec` under the hood. Some parameters like format, encoding, bits_per_sample, buffer_size, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's encoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.encoders.AudioEncoder
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:247: UserWarning: torio.io._streaming_media_encoder.StreamingMediaEncoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamWriter(uri, format=muxer, buffer_size=buffer_size)
# created 398 silence chunks from 6 background noise files
# ['./speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00000.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00001.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00002.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00003.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00004.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00005.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00006.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00007.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00008.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00009.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00010.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00011.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00012.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00013.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00014.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00015.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00016.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00017.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00018.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00019.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00020.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00021.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00022.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00023.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00024.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00025.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00026.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00027.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00028.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00029.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00030.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00031.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00032.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00033.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00034.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00035.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00036.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00037.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00038.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00039.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00040.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00041.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00042.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00043.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00044.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00045.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00046.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00047.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00048.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00049.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00050.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00051.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00052.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00053.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00054.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00055.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00056.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00057.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00058.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00059.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00060.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00061.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00062.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00063.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00064.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00065.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00066.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00067.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00068.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00069.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00070.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00071.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00072.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00073.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00074.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00075.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00076.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00077.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00078.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00079.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00080.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00081.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00082.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00083.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00084.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00085.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00086.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00087.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00088.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00089.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00090.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00091.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00092.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00093.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00094.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00095.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00096.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00097.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00098.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00099.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00100.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00101.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00102.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00103.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00104.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00105.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00106.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00107.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00108.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00109.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00110.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00111.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00112.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00113.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00114.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00115.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00116.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00117.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00118.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00119.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00120.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00121.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00122.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00123.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00124.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00125.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00126.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00127.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00128.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00129.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00130.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00131.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00132.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00133.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00134.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00135.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00136.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00137.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00138.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00139.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00140.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00141.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00142.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00143.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00144.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00145.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00146.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00147.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00148.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00149.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00150.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00151.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00152.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00153.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00154.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00155.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00156.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00157.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00158.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00159.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00160.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00161.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00162.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00163.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00164.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00165.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00166.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00167.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00168.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00169.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00170.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00171.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00172.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00173.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00174.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00175.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00176.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00177.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00178.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00179.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00180.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00181.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00182.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00183.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00184.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00185.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00186.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00187.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00188.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00189.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00190.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00191.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00192.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00193.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00194.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00195.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00196.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00197.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00198.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00199.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00200.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00201.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00202.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00203.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00204.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00205.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00206.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00207.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00208.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00209.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00210.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00211.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00212.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00213.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00214.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00215.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00216.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00217.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00218.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00219.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00220.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00221.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00222.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00223.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00224.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00225.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00226.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00227.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00228.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00229.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00230.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00231.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00232.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00233.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00234.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00235.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00236.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00237.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00238.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00239.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00240.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00241.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00242.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00243.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00244.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00245.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00246.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00247.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00248.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00249.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00250.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00251.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00252.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00253.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00254.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00255.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00256.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00257.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00258.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00259.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00260.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00261.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00262.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00263.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00264.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00265.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00266.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00267.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00268.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00269.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00270.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00271.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00272.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00273.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00274.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00275.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00276.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00277.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00278.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00279.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00280.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00281.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00282.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00283.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00284.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00285.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00286.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00287.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00288.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00289.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00290.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00291.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00292.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00293.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00294.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00295.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00296.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00297.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00298.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00299.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00300.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00301.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00302.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00303.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00304.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00305.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00306.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00307.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00308.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00309.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00310.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00311.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00312.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00313.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00314.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00315.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00316.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00317.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00318.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00319.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00320.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00321.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00322.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00323.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00324.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00325.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00326.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00327.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00328.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00329.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00330.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00331.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00332.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00333.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00334.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00335.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00336.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00337.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00338.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00339.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00340.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00341.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00342.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00343.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00344.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00345.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00346.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00347.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00348.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00349.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00350.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00351.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00352.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00353.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00354.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00355.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00356.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00357.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00358.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00359.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00360.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00361.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00362.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00363.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00364.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00365.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00366.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00367.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00368.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00369.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00370.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00371.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00372.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00373.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00374.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00375.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00376.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00377.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00378.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00379.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00380.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00381.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00382.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00383.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00384.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00385.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00386.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00387.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00388.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00389.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00390.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00391.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00392.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00393.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00394.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00395.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00396.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/_silence_/silence_00397.wav']

# %%
train_files, val_files, test_files = load_dataset_splits()
# Out:
# Dataset splits created:
#   Training: 85247 files
#   Validation: 9981 files
#   Testing: 11005 files

# %%
train_files
# Out:
# ['./speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8f811bbc_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ac4b3fc3_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7d5f87c8_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3847619e_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/23059a35_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/195c120a_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/fbb56351_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5ebc1cda_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e6327279_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/69a1a79f_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cd7f8c1b_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3589bc72_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1efdf53f_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0b40aa8e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/735845ab_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2f666bb2_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8e523821_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d394ef8e_nohash_7.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/42a99aec_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7ea032f3_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1c84a139_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/42a99aec_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0a196374_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e7334395_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/fa44fcf5_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bbc30633_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/65846c5f_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ace072ba_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/dae01802_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5fb88f4c_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bbd0bbd0_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0ba018fc_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/51c5601d_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d21fd169_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2e75d37a_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c98bbbd3_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/462e1919_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c39703ec_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b91b718c_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3c257192_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c22ebf46_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1c84a139_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/686d030b_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/93ec8b84_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b71ebf79_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7ff085e1_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2da58b32_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/311fde72_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/06a79a03_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/da040491_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/333784b7_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/235b444f_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a1e71565_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cd7f8c1b_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4a1e736b_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/fb727898_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b0f5b16d_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f2e9b610_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/64df20d8_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/773e26f7_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bbf38549_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3b3d2f59_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/90e72357_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d84829e0_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/742d6431_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/abbfc3b4_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/735845ab_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/238c112c_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/51055bda_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f0522ff4_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a24cf51c_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a5d1becc_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b8874962_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b5cf6ea8_nohash_5.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/29229c21_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b36c27c2_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/190821dc_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/86f12ac0_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e4200516_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d069e6ff_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7d86b703_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/31fd5cf5_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5e033479_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/86b1500e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/513aeddf_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/65f2531f_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3ee0fc39_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/61e2f74f_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a8cb6dda_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b575b5fb_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2cec1d47_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/29fb33da_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/85b877b5_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ab46af55_nohash_5.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6e41a77e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b6e6aa2e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/91bed2e0_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/18d120ae_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d394ef8e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/fb495c43_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/321aba74_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/837f7378_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/743edf9d_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4bb1244f_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c2aeb59d_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cce7416f_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5f8097e1_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2927c601_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cc3b5b62_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4e99c1b7_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9fac5701_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b4aa9fef_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/af790082_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1e9e6bdd_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a55105d0_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ace072ba_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f953e1af_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9307154f_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/da040491_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1a673010_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e4be0cf6_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4cee0c60_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3e549219_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9fac5701_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7e556a2c_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7910d292_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bd11a2e7_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9be15e93_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/23da904f_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0e6e36c9_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8fce59ff_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/365908bd_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7ce8df21_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/eeaf97c3_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a97017df_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/197f4153_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3c257192_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/94d370bf_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0b7ee1a0_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3102f006_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e0315cf6_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ddedba85_nohash_11.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/baeac2ba_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/af790082_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/64df20d8_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2fcb6397_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e7ea8b76_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9ce7a419_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/eaa83485_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2dc4f05d_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/31601aad_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3a182c98_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a7acbbeb_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f1d8a638_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/33903159_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6fca237d_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cc6ee39b_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a3fc7884_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e0315cf6_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1c1060b1_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e5afa9b0_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e4b02540_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b91b718c_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/11b1df78_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9e92ef0c_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a8688b67_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/dae01802_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/fbb2f6cc_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/30137d34_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/98ea0818_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/73124b26_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0f3f64d5_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a62f807b_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/11379f4d_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/dea820ce_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bbc30633_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8549f25d_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/333784b7_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a50a98d2_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/645ed69d_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1a994c9f_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ab9b93e4_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e53139ad_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5769c5ab_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2f0ce4d9_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3a3ee7ed_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a16013b7_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7c86c03e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a05a90c1_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7c83c5f6_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/51c5601d_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cc6ee39b_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/58df33b5_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/093f65a1_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b7a0754f_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9151f184_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8eb4a1bf_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/42ccb57a_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ee4a907f_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/333d7ddb_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/de89e2ca_nohash_7.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cce7416f_nohash_9.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d8521ea0_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f5733968_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3bc21161_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d264f7b6_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/63996b7c_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/65846c5f_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a05a90c1_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/be7a5b2d_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/833a0279_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/72242187_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/645ed69d_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4b3a7ad5_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/61e2f74f_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bcf614a2_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/953fe1ad_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/953fe1ad_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f1d8a638_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5d4e3bb8_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/fc3ba625_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9a76f8c3_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/528f9242_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0a2b400e_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6c429c7b_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/61ab8fbc_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6c429c7b_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/012c8314_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/81898f68_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/321aba74_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3209ec42_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/25e95412_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2da58b32_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/da2c5f1b_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ebdd0f59_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/eeaf97c3_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bdd22e4d_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0bfec55f_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/508e30ee_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cce7416f_nohash_11.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3e31dffe_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c351e611_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f953e1af_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ff4ed4f3_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6cb6eee7_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/28ed6bc9_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/256c0a05_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/40738a2d_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3b8406c0_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d0745d72_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7213ed54_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bab36420_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/aeb99b1c_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d070ea86_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bd76a7fd_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d0426d63_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a1cf7fd8_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/676f8138_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f9af0887_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6ef407da_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9b6c08ba_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/708b8d51_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b69fe0e2_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4c6944d6_nohash_5.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d8ed3745_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/baeac2ba_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/23059a35_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e102119e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2c6446f7_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e9bc5cc2_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/80b8eab4_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/38d78313_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/af6fbbf5_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ac9dee0e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b69002d4_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b4aa9fef_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8e05039f_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/226537ab_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b5cf6ea8_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b6573c88_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1a673010_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4c13fe25_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9e92ef0c_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4c3cddb8_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0e8ec1cb_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d2f4f431_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5c237956_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7846fd85_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/151bfb79_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5cf1ecce_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/928cc2ef_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3f45a0cf_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6fb3d5a7_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/676f8138_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a5d1becc_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/adec6a94_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5769c5ab_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1ffd513b_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/324210dd_nohash_5.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1496195a_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0c2ca723_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/adc216c5_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c50f55b8_nohash_7.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/46a153d8_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/197f4153_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2fee065a_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/611d2b50_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8a56f36e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f035e2ea_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/de89e2ca_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8b25410a_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ecbd8d66_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b00c4c53_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4c3cddb8_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b80d6c5e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/748cb308_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/234ab0fb_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/262d7a03_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ddedba85_nohash_10.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/23da904f_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/21832144_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f68160c0_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/64df20d8_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/18e910f4_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bb6d4301_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/23da904f_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/763188c4_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0e6e36c9_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d278d8ef_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/92521ccc_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0f7266cf_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cce7416f_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f6617a86_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/28e47b1a_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9a76f8c3_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/26a093e1_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/144d27ff_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/530306f5_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6aa8def4_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/179a61b7_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/07089da9_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8f4c551f_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5ab63b0a_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/459345ea_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/21cbe292_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e6be0830_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1e9e6bdd_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cce7416f_nohash_10.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3c257192_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ca4912b6_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/10ace7eb_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9c24bc76_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ec9b830b_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/042ea76c_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/51f7a034_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/300384f0_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bde0f20a_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d3a18257_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c08585c1_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/fbb2f6cc_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/29fb33da_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d84829e0_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b66f4f93_nohash_5.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f1d8a638_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8b25410a_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b0bad4a9_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ee1d8d49_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/042a8dde_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ac9dee0e_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/39a45230_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/530306f5_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b528edb3_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/25e95412_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b66f4f93_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f736ab63_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/460209ac_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8281a2a8_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8c888bbb_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8c3c4715_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f0522ff4_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/37d38e44_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bde0f20a_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/129c7d8d_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a7200079_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/91ffb786_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/833d9f56_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2250f5f2_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d31d8dd7_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d3f22f0e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bbaa7946_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/36de13e1_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c50f55b8_nohash_17.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c0445658_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b7a0754f_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f3957e23_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/617aeb6c_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/11099149_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6982fc2a_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/43691f67_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bf90a57a_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/824e8ce5_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8281a2a8_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9785931e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bd8412df_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/82305c3a_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4def68db_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e1936ce8_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/413bcfe1_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e9abfe31_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/60472d26_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c50f55b8_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8fce59ff_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1ed0b13d_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2b5e346d_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d430b3cc_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0d85a428_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/eeaf97c3_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6e74c582_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a2cc5444_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1b18600d_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/55d3725a_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/712e4d58_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1b63157b_nohash_5.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/fb8c31a9_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/40738a2d_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f19c1390_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/26e573a9_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/fbb56351_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/71d0ded4_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/833d9f56_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8ff44869_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4cee0c60_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b414c653_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a24582a0_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9efe5140_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bfaf2000_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5188de0d_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/215699ff_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c5a1e46c_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/de08912f_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/be7a5b2d_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/365908bd_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f568162b_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/978240e1_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/05739450_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/acfd5b5e_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/333784b7_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ae71797c_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8ea22de7_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8e05039f_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/de040337_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/fb8c31a9_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ace072ba_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b72e58c9_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/94403ad3_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b414c653_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3b3d2f59_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0d6d7360_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/129c7d8d_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f953e1af_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5ebc1cda_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3d53244b_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/15c563d7_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/97addd88_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/21e8c417_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bcf614a2_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3d9bbe2d_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a1e71565_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/30060aba_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ee1d8d49_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4a1e736b_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3bfd30e6_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f1d8a638_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3c8dc702_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c7e02d9c_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/94d370bf_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/779de043_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/fa57ab3b_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/14775481_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6904f0cb_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/144d27ff_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d264f7b6_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7211390b_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/da1d320c_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8b25410a_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/73124b26_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cb62dbf1_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/30a09789_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0f7266cf_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6af4aa07_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ece1a95a_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3cdecb0b_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9b027ecf_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ab46af55_nohash_6.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7fb8d703_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9fac5701_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/72320401_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/df1d5024_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/363c6bad_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/27c24504_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e7ebf59c_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3ee0fc39_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d9d08edd_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/da584bc0_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f2898d06_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/62f05757_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/96a48d28_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/017c4098_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9efe5140_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d5c41d6a_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/eb0676ec_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3402e488_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/131e738d_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/57152045_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/215699ff_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7f9eb952_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c93d5e22_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/73124b26_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9229bff9_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/fda46b78_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/773e26f7_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ddedba85_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d070ea86_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4e8c5516_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2dce72b3_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f0659908_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/dd6c6806_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/03cf93b1_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/22296dbe_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2fcb6397_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8a2d34d7_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f0659908_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f798ac78_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/72320401_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/80c17118_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/90645155_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/15c563d7_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/85851131_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/257251e0_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/834f03fe_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4e99c1b7_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0d2bcf9d_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/211b928a_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7e7ca854_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0b56bcfe_nohash_0.wav',
# ...
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5c39594f_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6414258b_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1cc80e39_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b29f8b23_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8dd788d8_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9ff1b8b6_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6347b393_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/46a153d8_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ace072ba_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/10c6d873_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/af6fbbf5_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/31d31fa0_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/845f8553_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f839238a_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cb2929ce_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/122c5aa7_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c120e80e_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/df1d5024_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b0bad4a9_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/42a99aec_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/de41f895_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/acfd5b5e_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b5cf6ea8_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3a3ee7ed_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/35d1b6ee_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/92a9c5e6_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/13199b79_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d070ea86_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/34d5aa5a_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/91ffb786_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4a1e736b_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c39703ec_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/35c29afe_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/645ed69d_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/47565088_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f5c3de1b_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3bb68054_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f216055e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7f9eb952_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6ace4fe1_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f68160c0_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f5626af6_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e7bcee8a_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8134f43f_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/332d33b1_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/94d370bf_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ccb1266b_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3ce4910e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f035e2ea_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/365908bd_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/05b2db80_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/179a61b7_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a16013b7_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b69002d4_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/472b8045_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d21fd169_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/508e30ee_nohash_5.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f44f440f_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e6327279_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5f9cd2eb_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/235b444f_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/da040491_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/28e47b1a_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ca58a8c6_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/eb0676ec_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/52162b51_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1ecfb537_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e900b652_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2b5e346d_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f550b7dc_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b5aacf2c_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/fac7deca_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c2dccf38_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/953fe1ad_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c4e00ee9_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b91b718c_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a8688b67_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/51995cea_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ac7840d8_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9b8a7439_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b15fc37d_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/fac74f6a_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/499be02e_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/da4ef063_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b29f8b23_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/14c7b073_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ab9b93e4_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/742d6431_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7d6b4b10_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/efab2cbd_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4ec7d027_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/9c06a3f3_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0d6d7360_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/16d41d07_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e7bcee8a_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/834f03fe_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1e412fac_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/07c5129e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d0fb9ff4_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8e69dc2f_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/617de221_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e9abfe31_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d94eb94f_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/de89e2ca_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/2b5e346d_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3389305e_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b528edb3_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f8f60f59_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4995d875_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/01bb6a2a_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/779de043_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8b25410a_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/324210dd_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7211390b_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/51f7a034_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/62581901_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1b88bf70_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/435f9f9e_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4e02d62d_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c50f55b8_nohash_11.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/7213ed54_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/559bc36a_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/67bdbf56_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bde0f20a_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/72242187_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/98ea0818_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cce7416f_nohash_7.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/78884794_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8a28231e_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/493392c6_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c351e611_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bbc30633_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8601f33b_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6c968bd9_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0d90d8e1_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3d9bbe2d_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c1e0e8e3_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/408de0a4_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/97101ef3_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8eb4a1bf_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cc4f9250_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c5c60d8d_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0585b66d_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e7ea8b76_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/f2e9b610_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4249c833_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c948d727_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/15c563d7_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/890cc926_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/caa7feaf_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/cdee383b_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/b31ad508_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/821b64cc_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/321aba74_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ffd2ba2f_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3d794813_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/5c39594f_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3209ec42_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/4995d875_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/a5d485dc_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1474273a_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0f46028a_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d278d8ef_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/3291330e_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c120e80e_nohash_5.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/0ac15fe9_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/d9aa8c90_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/dae01802_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/76424fa5_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6347b393_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/ec201020_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/e3e0f145_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/888a0c49_nohash_4.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8dd24423_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/1df99a8a_nohash_0.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/890cc926_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/6094340e_nohash_1.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/bcf614a2_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/8f4c551f_nohash_2.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/113b3fbc_nohash_3.wav',
#  './speech_commands_v2/SpeechCommands/speech_commands_v0.02/yes/c9b653a0_nohash_1.wav',
#  ...]

# %%
# convert data to mel spectrograms via torchaudio packages
import torch
import torchaudio
import matplotlib.pyplot as plt

# 1. Load the audio waveform
# For demonstration, we'll create a dummy waveform.
# In a real application, you would load from a file:
# waveform, sample_rate = torchaudio.load("path/to/your/audio.wav")
duration = 1  # seconds
waveform,sample_rate = torchaudio.load(train_files[0])
t = torch.linspace(0, duration, int(sample_rate * duration), dtype=torch.float32)


# 2. Define the Spectrogram transformation
# n_fft: size of the FFT window
# hop_length: number of samples between successive frames
# power: 2 for power spectrogram, 1 for magnitude spectrogram
spectrogram_transform = torchaudio.transforms.Spectrogram(
    n_fft=400,  # Example: 25ms window at 16kHz
    hop_length=160, # Example: 10ms hop
    power=2,    # Power spectrogram
)

# 3. Apply the Spectrogram transformation
spectrogram = spectrogram_transform(waveform)

# 4. Convert to log-magnitude
# Add a small epsilon to avoid log(0)
log_spectrogram = torch.log(spectrogram + 1e-8)

# 5. (Optional) Visualize the log spectrogram
plt.figure(figsize=(10, 4))
plt.imshow(log_spectrogram.squeeze(0).numpy(), aspect='auto', origin='lower', cmap='viridis')
# plt.title("Log-Magnitude Spectrogram")
# plt.xlabel("Time Frames")
# plt.ylabel("Frequency Bins")
# plt.colorbar(format="%+2.0f dB")

plt.axis('off')


plt.tight_layout(pad=0)

# To remove the huge white borders
plt.margins(0)

plt.savefig('foo.png')

# %%
def wav_to_png(wav_path,png_path):
  duration = 1  # seconds
  waveform,sample_rate = torchaudio.load(wav_path)
  t = torch.linspace(0, duration, int(sample_rate * duration), dtype=torch.float32)
  spectrogram_transform = torchaudio.transforms.Spectrogram(
    n_fft=400,  # Example: 25ms window at 16kHz
    hop_length=160, # Example: 10ms hop
    power=2,    # Power spectrogram
  )
  log_spectrogram = torch.log(spectrogram + 1e-8)
  plt.figure(figsize=(10, 4))
  plt.imshow(log_spectrogram.squeeze(0).numpy(), aspect='auto', origin='lower', cmap='Greys')
  plt.axis('off')
  plt.tight_layout(pad=0)
  plt.margins(0)
  plt.savefig(png_path)
  ####

# %%
# !mkdir imgs2
for i,img_path in enumerate(train_files[:100]):
  if i%25==0:
    print(i)
  wav_to_png(img_path,'./imgs2/'+str(i))

# %%
import matplotlib.image as mpimg
def png_to_arr(png_path):
  return mpimg.imread(png_path)[:,:,0]
png_to_arr('./imgs2/0.png')
# Out:
# array([[1.        , 1.        , 1.        , ..., 0.8862745 , 0.8862745 ,
#         0.8862745 ],
#        [1.        , 1.        , 1.        , ..., 0.8901961 , 0.8901961 ,
#         0.8901961 ],
#        [1.        , 1.        , 1.        , ..., 0.9019608 , 0.9019608 ,
#         0.9019608 ],
#        ...,
#        [0.3647059 , 0.3647059 , 0.3647059 , ..., 0.3529412 , 0.3529412 ,
#         0.3529412 ],
#        [0.30588236, 0.30588236, 0.30588236, ..., 0.29411766, 0.29411766,
#         0.29411766],
#        [0.29411766, 0.29411766, 0.29411766, ..., 0.28235295, 0.28235295,
#         0.28235295]], dtype=float32)

# %%
import matplotlib.image as mpimg
image_path = 'foo.png'  # Replace with the actual path to your image file
img = mpimg.imread(image_path)
plt.axis('off')
plt.imshow(img)
img[:,:,0]

#i'm sorry this is messy :(
#i will clean this up later
#also i will organize all of this
# Out:
# array([[0.26666668, 0.26666668, 0.26666668, ..., 0.25490198, 0.25490198,
#         0.25490198],
#        [0.26666668, 0.26666668, 0.26666668, ..., 0.25490198, 0.25490198,
#         0.25490198],
#        [0.26666668, 0.26666668, 0.26666668, ..., 0.25882354, 0.25882354,
#         0.25882354],
#        ...,
#        [0.27058825, 0.27058825, 0.27058825, ..., 0.2901961 , 0.2901961 ,
#         0.2901961 ],
#        [0.38039216, 0.38039216, 0.38039216, ..., 0.39607844, 0.39607844,
#         0.39607844],
#        [0.40392157, 0.40392157, 0.40392157, ..., 0.41960785, 0.41960785,
#         0.41960785]], dtype=float32)

# %%
plt.imshow(img[:,:,0], cmap='viridis', interpolation='nearest')

# %%
fig = plt.gcf()   # get current figure (the spectrogram you just plotted)
type(fig)
#type(plt.fig)
# Out:
# matplotlib.figure.Figure

# %%
sample_rate = 16000
duration = 1  # seconds
t = torch.linspace(0, duration, int(sample_rate * duration), dtype=torch.float32)
for i in range(1000):
  waveform,sample_rate = torchaudio.load(train_files[0])
  # 2. Define the Spectrogram transformation
  # n_fft: size of the FFT window
  # hop_length: number of samples between successive frames
  # power: 2 for power spectrogram, 1 for magnitude spectrogram
  spectrogram_transform = torchaudio.transforms.Spectrogram(
      n_fft=400,  # Example: 25ms window at 16kHz
      hop_length=160, # Example: 10ms hop
      power=2,    # Power spectrogram
  )

  # 3. Apply the Spectrogram transformation
  spectrogram = spectrogram_transform(waveform)

  # 4. Convert to log-magnitude
  # Add a small epsilon to avoid log(0)
  log_spectrogram = torch.log(spectrogram + 1e-8)

# %%
import torch
import torchaudio
import matplotlib.pyplot as plt

# 1. Load the audio waveform
# For demonstration, we'll create a dummy waveform.
# In a real application, you would load from a file:
# waveform, sample_rate = torchaudio.load("path/to/your/audio.wav")
sample_rate = 16000
duration = 1  # seconds
t = torch.linspace(0, duration, int(sample_rate * duration), dtype=torch.float32)
waveform = torch.sin(2 * torch.pi * 440 * t) + 0.5 * torch.sin(2 * torch.pi * 880 * t)
waveform = waveform.unsqueeze(0) # Add a channel dimension (batch, channel, time)

# 2. Define the Spectrogram transformation
# n_fft: size of the FFT window
# hop_length: number of samples between successive frames
# power: 2 for power spectrogram, 1 for magnitude spectrogram
spectrogram_transform = torchaudio.transforms.Spectrogram(
    n_fft=400,  # Example: 25ms window at 16kHz
    hop_length=160, # Example: 10ms hop
    power=2,    # Power spectrogram
)

# 3. Apply the Spectrogram transformation
spectrogram = spectrogram_transform(waveform)

# 4. Convert to log-magnitude
# Add a small epsilon to avoid log(0)
log_spectrogram = torch.log(spectrogram + 1e-8)

# 5. (Optional) Visualize the log spectrogram
plt.figure(figsize=(10, 4))
plt.imshow(log_spectrogram.squeeze(0).numpy(), aspect='auto', origin='lower', cmap='viridis')
plt.title("Log-Magnitude Spectrogram")
plt.xlabel("Time Frames")
plt.ylabel("Frequency Bins")
plt.colorbar(format="%+2.0f dB")
plt.show()

# %%
waveform = torch.sin(2 * torch.pi * 440 * t) + 0.5 * torch.sin(2 * torch.pi * 880 * t)
#waveform=torch.
type(waveform)
# Out:
# torch.Tensor

# %%
# data augmentation strategy:
# 1. randomly select _silence_ chunk and add to training sample at random, low SNR
# 2. randomly shift waveform left or right by small margin (100-200 ms), padding with silence
# (after transforming to 2D)
# 3. randomly mask out frequency bands using torchaudio
# 4. randomly mask time steps using torch audio

# %%
# implement a custom class SpeechCommandsDataset(torch.utils.data.Dataset).
# __init__(self, file_paths, transform_pipeline, augmentation_pipeline): Stores file paths, labels, and the transform/augmentation objects.
# __getitem__(self, idx):
  # loads the .wav file at idx using torchaudio.load().
  # verifies/pads/truncates waveform to exactly 16,000 samples.
  # applies augmentations (if it's the training set).
  # applies the Mel Spectrogram transformation pipeline.
  # returns the (spectrogram_tensor, label_tensor).
import random
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

class SpeechCommandsDataset(Dataset):
    def __init__(
        self,
        file_paths,
        mode="train",
        sample_rate=16000,
        n_fft=400,
        hop_length=160,
        time_mask_param=20,
        freq_mask_param=10,
    ):
        """
        file_paths: list of .wav paths (train_files / val_files / test_files)
        mode: "train", "val", or "test" (controls augmentations)
        """
        self.file_paths = file_paths
        self.mode = mode
        self.sample_rate = sample_rate
        self.num_samples = sample_rate  # 1 second

        # Spectrogram transform (same settings as your earlier demo cell)
        self.spectrogram_transform = torchaudio.transforms.Spectrogram(
            n_fft=n_fft,
            hop_length=hop_length,
            power=2,
        )

        # Data augmentation (only used in training)
        if mode == "train":
            self.time_mask = torchaudio.transforms.TimeMasking(time_mask_param=time_mask_param)
            self.freq_mask = torchaudio.transforms.FrequencyMasking(freq_mask_param=freq_mask_param)
        else:
            self.time_mask = None
            self.freq_mask = None

    def __len__(self):
        return len(self.file_paths)

    def _load_and_fix_waveform(self, wav_path):
        """
        Loads the waveform, converts to mono, and pads/truncates to exactly self.num_samples.
        """
        waveform, sr = torchaudio.load(wav_path)

        # If needed, resample to target sample_rate
        if sr != self.sample_rate:
            waveform = torchaudio.functional.resample(waveform, sr, self.sample_rate)

        # Ensure mono (keep first channel)
        if waveform.shape[0] > 1:
            waveform = waveform[:1, :]

        # Pad or truncate to fixed length
        num_current = waveform.shape[1]
        if num_current < self.num_samples:
            pad_amount = self.num_samples - num_current
            waveform = F.pad(waveform, (0, pad_amount))
        elif num_current > self.num_samples:
            waveform = waveform[:, : self.num_samples]

        return waveform

    def _get_label_from_path(self, wav_path):
        """
        Extract the word class from the directory name and map it with get_label().
        Example:
          .../speech_commands_v0.02/yes/0a7c2a8d_nohash_0.wav -> 'yes'
          .../speech_commands_v0.02/_silence_/silence_00001.wav -> '_silence_'
        """
        word_class = os.path.basename(os.path.dirname(wav_path))  # e.g. 'yes', 'no', '_silence_'
        return get_label(word_class)

    def _random_time_shift(self, waveform, max_shift_seconds=0.2):
        """
        Randomly shift waveform left/right by up to max_shift_seconds.
        """
        max_shift = int(max_shift_seconds * self.sample_rate)
        if max_shift == 0:
            return waveform

        shift = random.randint(-max_shift, max_shift)
        if shift > 0:
            # shift right: pad on left, cut at end
            waveform = F.pad(waveform, (shift, 0))[:, :-shift]
        elif shift < 0:
            # shift left: pad on right, cut at beginning
            shift = -shift
            waveform = F.pad(waveform, (0, shift))[:, shift:]
        return waveform

    def _waveform_to_log_spectrogram(self, waveform):
        """
        Apply spectrogram transform and log-scaling.
        Output shape: [1, freq_bins, time_steps]
        """
        spectrogram = self.spectrogram_transform(waveform)
        log_spectrogram = torch.log(spectrogram + 1e-8)

        # Optional: normalize per example
        mean = log_spectrogram.mean()
        std = log_spectrogram.std()
        log_spectrogram = (log_spectrogram - mean) / (std + 1e-9)

        return log_spectrogram

    def __getitem__(self, idx):
        wav_path = self.file_paths[idx]

        # 1. Load and fix waveform length
        waveform = self._load_and_fix_waveform(wav_path)

        # 2. Data augmentation (training only)
        if self.mode == "train":
            waveform = self._random_time_shift(waveform)

        # 3. Convert to log-spectrogram
        log_spec = self._waveform_to_log_spectrogram(waveform)

        # 4. Label
        label = self._get_label_from_path(wav_path)
        label = torch.tensor(label, dtype=torch.long)

        return log_spec, label

# %%
# initialize pytorch dataloaders
# instantiate three DataLoader objects (train, val, test) from Dataset instances
# train_loader: shuffle=True, batch_size, num_workers (for parallel loading)
# val_loader & test_loader: shuffle=False, same batch_size, num_workers.

# Hyperparameters for loading
batch_size = 64
num_workers = 2  # adjust depending on your machine

# Create Dataset instances
train_dataset = SpeechCommandsDataset(train_files, mode="train")
val_dataset   = SpeechCommandsDataset(val_files,   mode="val")
test_dataset  = SpeechCommandsDataset(test_files,  mode="test")

# Create DataLoaders
train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
    pin_memory=True,
)

val_loader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers,
    pin_memory=True,
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers,
    pin_memory=True,
)

len(train_dataset), len(val_dataset), len(test_dataset)
# Out:
# (85247, 9981, 11005)

# %%
class ShallowSpeechCNN(nn.Module):
    """
    A shallow CNN consisting of two convolutional blocks
    followed by two fully connected layers.
    """
    def __init__(self, num_classes):
        """
        initializes the layers of the neural network

        Args:
            num_classes (int): The number of output classes
        """
        super(ShallowSpeechCNN, self).__init__()

        # conv block 1
        # input shape: (batch_size, 1, n_mels, n_frames)
        # assume single input channel (grayscale spectrogram)
        self.conv1 = nn.Conv2d(
            in_channels=1,
            out_channels=16,
            kernel_size=(3, 3),
            stride=(1, 1),
            padding=1
        )
        # output shape: (batch_size, 16, n_mels, n_frames)
        self.bn1 = nn.BatchNorm2d(16)
        # max pooling reduces spatial dimensions
        self.pool1 = nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2))
        # output shape: (batch_size, 16, n_mels/2, n_frames/2)

        # conv block 2
        self.conv2 = nn.Conv2d(
            in_channels=16,
            out_channels=32,
            kernel_size=(3, 3),
            stride=(1, 1),
            padding=1
        )
        # output shape: (batch_size, 32, n_mels/2, n_frames/2)
        self.bn2 = nn.BatchNorm2d(32)
        self.pool2 = nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2))
        # output shape: (batch_size, 32, n_mels/4, n_frames/4)

        # adaptive pooling layer
        # makes network more robust to slight variations
        # in input spectrogram size (i.e. due to audio length)
        # forces output of conv blocks to fixed size (4x4)
        self.adaptive_pool = nn.AdaptiveAvgPool2d((4, 4))
        # output shape: (batch_size, 32, 4, 4)

        # fully connected layers
        # flattened feature size will be 32 * 4 * 4 = 512
        self.fc1 = nn.Linear(in_features=32 * 4 * 4, out_features=64)

        # output layer
        self.fc2 = nn.Linear(in_features=64, out_features=num_classes)

    def forward(self, x):
        """
        defines forward pass of the network

        Args:
            x (torch.Tensor): input batch of Mel spectrograms
                              Shape: (batch_size, 1, n_mels, n_frames)

        Returns:
            torch.Tensor: raw, unnormalized logits for each class
                          Shape: (batch_size, num_classes)
        """
        # conv block 1
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)
        x = self.pool1(x)

        # conv block 2
        x = self.conv2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = self.pool2(x)

        # adaptive pooling
        x = self.adaptive_pool(x)

        # flatten features for fully connected layers
        # shape changes from (batch_size, 32, 4, 4) to (batch_size, 512)
        x = torch.flatten(x, start_dim=1)

        # fully connected layer
        x = self.fc1(x)
        x = F.relu(x)

        # output layer (logits)
        # no activation function here, nn.CrossEntropyLoss expects raw logits
        x = self.fc2(x)

        return x

# %%
num_classes = 12
model = ShallowSpeechCNN(num_classes=num_classes)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

print(f"Model instantiated: {model.__class__.__name__} with {num_classes} classes")
print(f"Loss function: {criterion.__class__.__name__}")
print(f"Optimizer: {optimizer.__class__.__name__} with learning rate {optimizer.defaults['lr']}")
# Out:
# Model instantiated: ShallowSpeechCNN with 12 classes
# Loss function: CrossEntropyLoss
# Optimizer: Adam with learning rate 0.001

# %%
def train_epoch(model, data_loader, criterion, optimizer, device):
    model.train()  # set model to training mode
    total_loss = 0

    # iterate through data_loader with tqdm for progress bar
    for inputs, labels in tqdm.tqdm(data_loader, desc="Training Epoch"): # desc is description for the progress bar
        inputs = inputs.to(device)  # move inputs to specified device
        labels = labels.to(device)  # move labels to specified device

        optimizer.zero_grad()  # zero out the gradients

        outputs = model(inputs)  # perform forward pass
        loss = criterion(outputs, labels)  # calculate the loss

        loss.backward()  # perform backward pass
        optimizer.step()  # update model's weights

        total_loss += loss.item()  # accumulate the loss

    return total_loss / len(data_loader)  # return the average loss for the epoch

# %%
def val_epoch(model, data_loader, criterion, device):
    model.eval()  # set model to evaluation mode
    total_loss = 0
    correct_predictions = 0
    total_samples = 0

    # ensure no gradients are calculated during validation
    with torch.no_grad():
        for inputs, labels in tqdm.tqdm(data_loader, desc="Validation Epoch"):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)  # perform forward pass
            loss = criterion(outputs, labels)  # calculate the loss

            total_loss += loss.item() * inputs.size(0)  # accumulate batch loss, weighted by batch size

            # calculate accuracy
            _, predicted = torch.max(outputs.data, 1)
            total_samples += labels.size(0)
            correct_predictions += (predicted == labels).sum().item()

    avg_loss = total_loss / total_samples
    accuracy = correct_predictions / total_samples

    return avg_loss, accuracy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_losses = []
val_losses = []
val_accuracies = []

num_epochs = 10
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

best_val_loss = float('inf')
checkpoint_path = '/content/drive/MyDrive/my_cnn_checkpoint.pth'

print(f"Training on: {device}")

for epoch in range(num_epochs):

    train_loss = train_epoch(model, train_loader, criterion, optimizer, device)
    val_loss, val_accuracy = val_epoch(model, val_loader, criterion, device)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        print(f"New best model found! Saving checkpoint for epoch {epoch}...")

        checkpoint = {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_val_loss': best_val_loss,
            'accuracy': val_accuracy,
            'train_losses': train_losses,
            'val_losses': val_losses,
            'val_accuracies': val_accuracies
        }


        torch.save(checkpoint, checkpoint_path)

    else:
        print(f"Validation loss did not improve at epoch {epoch}. Current best: {best_val_loss:.4f}")

print("Training complete.")
# Out:
# Training on: cuda
# Training Epoch:   0%|          | 0/1332 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Training Epoch: 100%|██████████| 1332/1332 [05:19<00:00,  4.17it/s]
# Validation Epoch:   0%|          | 0/156 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Validation Epoch: 100%|██████████| 156/156 [00:35<00:00,  4.40it/s]
# New best model found! Saving checkpoint for epoch 0...
# Training Epoch:   0%|          | 0/1332 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Training Epoch: 100%|██████████| 1332/1332 [05:18<00:00,  4.18it/s]
# Validation Epoch:   0%|          | 0/156 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Validation Epoch: 100%|██████████| 156/156 [00:35<00:00,  4.42it/s]
# New best model found! Saving checkpoint for epoch 1...
# Training Epoch:   0%|          | 0/1332 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Training Epoch: 100%|██████████| 1332/1332 [05:22<00:00,  4.13it/s]
# Validation Epoch:   0%|          | 0/156 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Validation Epoch: 100%|██████████| 156/156 [00:34<00:00,  4.54it/s]
# New best model found! Saving checkpoint for epoch 2...
# Training Epoch:   0%|          | 0/1332 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Training Epoch: 100%|██████████| 1332/1332 [05:21<00:00,  4.14it/s]
# Validation Epoch:   0%|          | 0/156 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Validation Epoch: 100%|██████████| 156/156 [00:34<00:00,  4.51it/s]
# New best model found! Saving checkpoint for epoch 3...
# Training Epoch:   0%|          | 0/1332 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Training Epoch: 100%|██████████| 1332/1332 [05:20<00:00,  4.15it/s]
# Validation Epoch:   0%|          | 0/156 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Validation Epoch: 100%|██████████| 156/156 [00:34<00:00,  4.47it/s]
# New best model found! Saving checkpoint for epoch 4...
# Training Epoch:   0%|          | 0/1332 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Training Epoch: 100%|██████████| 1332/1332 [05:17<00:00,  4.20it/s]
# Validation Epoch:   0%|          | 0/156 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Validation Epoch: 100%|██████████| 156/156 [00:34<00:00,  4.59it/s]
# New best model found! Saving checkpoint for epoch 5...
# Training Epoch:   0%|          | 0/1332 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Training Epoch: 100%|██████████| 1332/1332 [05:17<00:00,  4.19it/s]
# Validation Epoch:   0%|          | 0/156 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Validation Epoch: 100%|██████████| 156/156 [00:35<00:00,  4.37it/s]
# New best model found! Saving checkpoint for epoch 6...
# Training Epoch:   0%|          | 0/1332 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Training Epoch: 100%|██████████| 1332/1332 [05:17<00:00,  4.19it/s]
# Validation Epoch:   0%|          | 0/156 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Validation Epoch: 100%|██████████| 156/156 [00:34<00:00,  4.47it/s]
# New best model found! Saving checkpoint for epoch 7...
# Training Epoch:   0%|          | 0/1332 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Training Epoch: 100%|██████████| 1332/1332 [05:17<00:00,  4.19it/s]
# Validation Epoch:   0%|          | 0/156 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Validation Epoch: 100%|██████████| 156/156 [00:35<00:00,  4.43it/s]
# Validation loss did not improve at epoch 8. Current best: 0.6817
# Training Epoch:   0%|          | 0/1332 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Training Epoch: 100%|██████████| 1332/1332 [05:17<00:00,  4.20it/s]
# Validation Epoch:   0%|          | 0/156 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# Validation Epoch: 100%|██████████| 156/156 [00:35<00:00,  4.38it/s]
# New best model found! Saving checkpoint for epoch 9...
# Training complete.

# %%
# find optimal set of hyperparameters using optuna
# WRITE CODE HERE

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
checkpoint = torch.load(checkpoint_path, map_location=device)

# load the model's learned parameters
model.load_state_dict(checkpoint['model_state_dict'])

# load other info if needed (e.g., for plotting)
# train_losses = checkpoint.get('train_losses', [])
# val_losses = checkpoint.get('val_losses', [])
# print(f"model loaded. trained for {checkpoint.get('epoch', 'N/A')} epochs.")
print(f"model loaded. best val loss was: {checkpoint.get('best_val_loss', 'N/A'):.4f}")


# this disables dropout and batch normalization updates
model.eval()
print("model set to evaluation mode.")

# test run
all_preds = []
all_labels = []

# disable gradient calculations during inference
with torch.no_grad():
    # wrap test_loader in tqdm for a progress bar
    for inputs, labels in tqdm.tqdm(test_loader, desc="testing"):
        # move data to the correct device
        inputs = inputs.to(device)
        labels = labels.to(device)

        # forward pass
        outputs = model(inputs)

        # get the predicted class (index with highest logit)
        _, predicted = torch.max(outputs.data, 1)

        # move predictions and labels to cpu to store in lists
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

print("evaluation complete.")
# Out:
# model loaded. best val loss was: 0.6358
# model set to evaluation mode.
# testing:   0%|          | 0/172 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# testing: 100%|██████████| 172/172 [00:40<00:00,  4.21it/s]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# evaluation complete.
#
# --- classification report ---
# WARNING: 'class_names' list not defined. metrics will not have labels.
#               precision    recall  f1-score   support
#
#            0       0.93      0.74      0.83       419
#            1       0.71      0.17      0.28       405
#            2       0.68      0.60      0.63       425
#            3       0.57      0.48      0.52       406
#            4       0.83      0.54      0.66       412
#            5       0.69      0.65      0.67       396
#            6       0.55      0.08      0.13       396
#            7       0.69      0.61      0.65       402
#            8       0.87      0.76      0.82       411
#            9       0.47      0.37      0.41       402
#           10       0.81      0.94      0.87      6931
#           11       0.00      0.00      0.00         0
#
#     accuracy                           0.78     11005
#    macro avg       0.65      0.50      0.54     11005
# weighted avg       0.77      0.78      0.76     11005
#
# WARNING: 'class_names' not defined. matrix will not have labels.
# plot displayed.

# %%
class_names = [
    'yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go',
    '_unknown_', '_silence_'
]

# calculate and print per-class precision, recall, f1-score
# ensure class_names defined for proper labeling
if 'class_names' in locals() and class_names:
    report = classification_report(all_labels, all_preds, target_names=class_names, zero_division=0)
    print(report)
else:
    print("WARNING: 'class_names' list not defined. metrics will not have labels.")
    report = classification_report(all_labels, all_preds, zero_division=0)
    print(report)


# calculate confusion matrix
cm = confusion_matrix(all_labels, all_preds)


plt.figure(figsize=(10, 8))
if 'class_names' in locals() and class_names:
    # use class_names for x and y tick labels
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
else:
    print("WARNING: 'class_names' not defined. matrix will not have labels.")
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')

plt.title('confusion matrix')
plt.ylabel('true label')
plt.xlabel('predicted label')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          yes       0.93      0.74      0.83       419
#           no       0.71      0.17      0.28       405
#           up       0.68      0.60      0.63       425
#         down       0.57      0.48      0.52       406
#         left       0.83      0.54      0.66       412
#        right       0.69      0.65      0.67       396
#           on       0.55      0.08      0.13       396
#          off       0.69      0.61      0.65       402
#         stop       0.87      0.76      0.82       411
#           go       0.47      0.37      0.41       402
#    _unknown_       0.81      0.94      0.87      6931
#    _silence_       0.00      0.00      0.00         0
#
#     accuracy                           0.78     11005
#    macro avg       0.65      0.50      0.54     11005
# weighted avg       0.77      0.78      0.76     11005
# plot displayed.
